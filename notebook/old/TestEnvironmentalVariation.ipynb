# %%
using Plots: plot

include("../src/EnvironmentalVariation.jl")
using Main.EnvironmentalVariation

# %%
var_vec = ar1(Float64(100), Float64(1), 0.7, 3, 100)
display(plot(var_vec))
var_vec = prune(var_vec, 1000.0, 10.0)
var_vec = smoothen(var_vec, 1.5)
plot(var_vec)

# %%
var_vec = ar1(100, 100, 0.1, 3, 100)
display(plot(var_vec))
desc(var_vec)

var_vec = prune(var_vec, 1000, 10)
var_vec = smoothen(var_vec, 1.5)
display(plot(var_vec))
desc(var_vec)
# Out:
# Summary Stats:
# Length:         100
# Missing Count:  0
# Mean:           89.790000
# Minimum:        -66.000000
# 1st Quartile:   11.750000
# Median:         68.000000
# 3rd Quartile:   178.000000
# Maximum:        303.000000
# Type:           Int64
# Std:            106.818102
# Summary Stats:
# Length:         100
# Missing Count:  0
# Mean:           77.550000
# Minimum:        10.000000
# 1st Quartile:   32.250000
# Median:         62.500000
# 3rd Quartile:   100.500000
# Maximum:        278.000000
# Type:           Int64
# Std:            60.967184

# %%
var_vec = two_level_var(10, 5, 100, 2, 17)
display(plot(var_vec))
desc(var_vec)
var_vec = prune(var_vec, 100, 10)
var_vec = smoothen(var_vec, 1.5)
display(plot(var_vec))
desc(var_vec)
# Out:
# Summary Stats:
# Length:         17
# Missing Count:  0
# Mean:           31.176471
# Minimum:        10.000000
# 1st Quartile:   10.000000
# Median:         10.000000
# 3rd Quartile:   10.000000
# Maximum:        100.000000
# Type:           Int64
# Std:            39.351358
# Summary Stats:
# Length:         17
# Missing Count:  0
# Mean:           12.588235
# Minimum:        10.000000
# 1st Quartile:   10.000000
# Median:         10.000000
# 3rd Quartile:   15.000000
# Maximum:        22.000000
# Type:           Int64
# Std:            4.139125

# %%
var_vec = two_level_var(10, 40, 100, 20, 170)
display(plot(var_vec))
var_vec = prune(var_vec, 100, 10)
var_vec = smoothen(var_vec, 1.5)
display(plot(var_vec))
desc(var_vec)
# Out:
# Summary Stats:
# Length:         170
# Missing Count:  0
# Mean:           32.558824
# Minimum:        10.000000
# 1st Quartile:   10.000000
# Median:         10.000000
# 3rd Quartile:   48.750000
# Maximum:        100.000000
# Type:           Int64
# Std:            36.611014

# %%
var_vec = two_level_var(10, 500, 100, 500, 1000)
display(plot(var_vec))
var_vec = prune(var_vec, 100, 10)
var_vec = smoothen(var_vec, 1.1)
display(plot(var_vec))
desc(var_vec)
# Out:
# Summary Stats:
# Length:         1000
# Missing Count:  0
# Mean:           53.496000
# Minimum:        10.000000
# 1st Quartile:   10.000000
# Median:         10.500000
# 3rd Quartile:   100.000000
# Maximum:        100.000000
# Type:           Int64
# Std:            44.683494
