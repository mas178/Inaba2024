# %%
using Colors
using Compose
using GraphPlot
using Graphs
using SimpleWeightedGraphs
using Plots

import Cairo, Fontconfig
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %% [markdown]
# # Weighted Undirected Complete Graph ($G_W$)

# %%
N = 10
gW = SimpleWeightedGraph(N)

for x in 1:N
    for y in 1:N
        if x < y
            if (x, y) ∈ [(1, 2), (3, 4), (6, 7), (6, 8), (3, 9), (4, 9), (4, 10), (9, 10)]
                add_edge!(gW, x, y, rand(0.8:0.1:0.9))
            else
                add_edge!(gW, x, y, rand(0.1:0.1:0.3))
            end
        end
    end
end

weight_vec = [round(get_weight(gW, e.src, e.dst), digits=2) for e in edges(gW)]

p = gplot(
    gW,
    layout=circular_layout,
    nodelabel=1:N,
    nodefillc=colorant"lightgray", 
    edgelabel=weight_vec,
    edgelinewidth=weight_vec.^2,
    edgestrokec=colorant"gray",
)
display(p)
draw(PNG("../img/HBESJ/Network1.png"), p);
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.976659085588597cx, 0.07553278569230427cy), (0.8323579087863503cx, 0.5425012030575906cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9550582608824103cx, 0.06504029585638817cy), (0.3539587334925372cx, 0.9349597041436118cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.7461940422429189cx, 0.6660264536315494cy), (0.37183994650697605cx, 0.9520075351183455cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9371770478679714cx, 0.04799246488165452cy), (-0.24619404224291874cx, 0.9520075351183455cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.7342055279974352cx, 0.643592636962317cy), (-0.23420552799743505cx, 0.9744413517875778cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.22996005287073795cx, 1.0cy), (-0.22996005287073784cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9251885336224878cx, 0.025558648212422184cy), (-0.7342055279974351cx, 0.592475340537473cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.729960052870738cx, 0.6180339887498949cy), (-0.7299600528707378cx, 0.6180339887498951cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.23420552799743516cx, 0.9744413517875778cy), (-0.7342055279974351cx, 0.6435926369623173cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.371839946506976cx, 0.9520075351183455cy), (-0.7461940422429187cx, 0.6660264536315497cy)])  …  Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.22996005287073806cx, -0.9999999999999999cy), (0.22996005287073773cx, -1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9766590855885972cx, -0.07553278569230427cy), (0.8323579087863503cx, -0.5425012030575909cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.8090169943749475cx, 0.5389770472456854cy), (0.8090169943749475cx, -0.5389770472456856cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.33235790878635035cx, 0.9244672143076957cy), (0.7856760799635446cx, -0.5425012030575909cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.2640752552573576cx, 0.9349597041436118cy), (0.7640752552573578cx, -0.552993692893507cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7461940422429187cx, 0.5700415238682406cy), (0.7461940422429189cx, -0.5700415238682406cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9251885336224878cx, -0.02555864821242195cy), (0.7342055279974352cx, -0.592475340537473cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.729960052870738cx, -0.6180339887498947cy), (0.729960052870738cx, -0.6180339887498951cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.23420552799743527cx, -0.9744413517875777cy), (0.7342055279974351cx, -0.6435926369623173cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.3718399465069759cx, -0.9520075351183455cy), (0.7461940422429189cx, -0.6660264536315496cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.011712139482105111mm), Compose.LineWidthPrimitive(0.04684855792842044 ...

# %% [markdown]
# # Undirected Unconnected Graph

# %%
for (i, t) in enumerate([0.75, 0.25])
    gT = SimpleWeightedGraph([w > t ? w : 0.0 for w in weights(gW)])
    weight_vec = [round(get_weight(gT, e.src, e.dst), digits=2) for e in edges(gT)]
    p = gplot(
        gT,
        layout=circular_layout,
        nodelabel=1:N,
        nodefillc=colorant"lightgray", 
        edgelabel=weight_vec,
        edgelinewidth=weight_vec.^2,
        edgestrokec=colorant"gray",
    )
    display(p)
    draw(PNG("../img/HBESJ/Network$(i+1).png"), p)
end
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.976659085588597cx, 0.07553278569230427cy), (0.8323579087863503cx, 0.5425012030575906cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.22996005287073795cx, 1.0cy), (-0.22996005287073784cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9766590855885972cx, -0.07553278569230405cy), (-0.8323579087863503cx, -0.5425012030575904cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9550582608824103cx, -0.06504029585638794cy), (-0.35395873349253726cx, -0.9349597041436117cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.30901699437494745cx, 0.9209430584957905cy), (0.30901699437494723cx, -0.9209430584957905cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.28567607996354444cx, 0.9244672143076957cy), (0.2856760799635444cx, -0.9244672143076957cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.2640752552573576cx, 0.9349597041436118cy), (0.7640752552573578cx, -0.552993692893507cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.3718399465069759cx, -0.9520075351183455cy), (0.7461940422429189cx, -0.6660264536315496cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.7495769268547271mm)]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.7495769268547271mm)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, Measures.Length{:cy, Float64}}, Rotation{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}, Tuple{Measures.AbsoluteLength, Measures.AbsoluteLength}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx, Float64}, M ...
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.976659085588597cx, 0.07553278569230427cy), (0.8323579087863503cx, 0.5425012030575906cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9550582608824103cx, 0.06504029585638817cy), (0.3539587334925372cx, 0.9349597041436118cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.7461940422429189cx, 0.6660264536315494cy), (0.37183994650697605cx, 0.9520075351183455cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.22996005287073795cx, 1.0cy), (-0.22996005287073784cx, 1.0cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.729960052870738cx, 0.6180339887498949cy), (-0.7299600528707378cx, 0.6180339887498951cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.7342055279974352cx, 0.5924753405374727cy), (-0.9251885336224878cx, 0.025558648212422364cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9766590855885972cx, -0.07553278569230405cy), (-0.8323579087863503cx, -0.5425012030575904cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.7640752552573578cx, 0.5529936928935067cy), (-0.2640752552573578cx, -0.9349597041436117cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7856760799635445cx, 0.5425012030575909cy), (-0.3323579087863504cx, -0.9244672143076956cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9550582608824103cx, -0.06504029585638794cy), (-0.35395873349253726cx, -0.9349597041436117cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7461940422429189cx, -0.6660264536315492cy), (-0.37183994650697616cx, -0.9520075351183453cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.30901699437494745cx, 0.9209430584957905cy), (0.30901699437494723cx, -0.9209430584957905cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.28567607996354444cx, 0.9244672143076957cy), (0.2856760799635444cx, -0.9244672143076957cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7640752552573576cx, 0.552993692893507cy), (0.26407525525735753cx, -0.9349597041436118cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7342055279974352cx, -0.6435926369623168cy), (0.23420552799743496cx, -0.9744413517875778cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9766590855885972cx, -0.07553278569230427cy), (0.8323579087863503cx, -0.5425012030575909cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.2640752552573576cx, 0.9349597041436118cy), (0.7640752552573578cx, -0.552993692893507cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7461940422429187cx, 0.5700415238682406cy), (0.7461940422429189cx, -0.5700415238682406cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.3718399465069759cx, -0.9520075351183455cy), (0.7461940422429189cx, -0.6660264536315496cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.7495769268547271mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.10540925533894598mm), Compose.LineWidthPrimitive(0.9486832980505139mm), Compose.LineWidthPrimitive(0.105409255 ...
